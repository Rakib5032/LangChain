# %%
# !pip install -U langchain langchain-core langchain-community langchain-openai chromadb faiss-cpu openai tiktoken wikipedia
# Out:
# Requirement already satisfied: langchain in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.2.15)
# Collecting langchain
#   Downloading langchain-1.2.18-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-core in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.3.0)
# Collecting langchain-core
#   Downloading langchain_core-1.3.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langchain-community in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.1.12)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: chromadb in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.5.9)
# Requirement already satisfied: faiss-cpu in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.13.2)
# Requirement already satisfied: openai in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (2.31.0)
# Collecting openai
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: tiktoken in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (0.12.0)
# Requirement already satisfied: wikipedia in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (1.4.0)
# Collecting langgraph<1.2.0,>=1.1.10 (from langchain)
#   Downloading langgraph-1.1.10-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.1)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.12 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.13.0)
# Requirement already satisfied: certifi in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (2.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: greenlet>=1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from tiktoken) (2026.4.4)
# Requirement already satisfied: build>=1.0.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.46.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.25.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: tokenizers>=0.13.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: beautifulsoup4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from wikipedia) (4.14.3)
# Requirement already satisfied: pyproject_hooks in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.10.2)
# Requirement already satisfied: filelock>=3.10.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.3)
# Requirement already satisfied: click>=8.2.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from typer>=0.9.0->chromadb) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from beautifulsoup4->wikipedia) (2.8.3)
# Requirement already satisfied: oauthlib>=3.0.0 in D:\My projects\LangChain\LangChain Models\venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading langchain-1.2.18-py3-none-any.whl (113 kB)
# Downloading langchain_core-1.3.3-py3-none-any.whl (543 kB)
#    ---------------------------------------- 0.0/543.9 kB ? eta -:--:--
#    ---------------------------------------- 543.9/543.9 kB 3.6 MB/s  0:00:00
# Downloading langgraph-1.1.10-py3-none-any.whl (173 kB)
# Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl (37 kB)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 7.4 MB/s  0:00:00
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Installing collected packages: langchain-protocol, openai, langchain-core, langchain-openai, langgraph-prebuilt, langgraph, langchain
#
#   Attempting uninstall: openai
#
#     Found existing installation: openai 2.31.0
#
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#     Uninstalling openai-2.31.0:
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#       Successfully uninstalled openai-2.31.0
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#    ----- ---------------------------------- 1/7 [openai]
#   Attempting uninstall: langchain-core
#    ----- ---------------------------------- 1/7 [openai]
#     Found existing installation: langchain-core 1.3.0
#    ----- ---------------------------------- 1/7 [openai]
#     Uninstalling langchain-core-1.3.0:
#    ----- ---------------------------------- 1/7 [openai]
#       Successfully uninstalled langchain-core-1.3.0
#    ----- ---------------------------------- 1/7 [openai]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#   Attempting uninstall: langchain-openai
#    ----------- ---------------------------- 2/7 [langchain-core]
#     Found existing installation: langchain-openai 1.1.12
#    ----------- ---------------------------- 2/7 [langchain-core]
#     Uninstalling langchain-openai-1.1.12:
#    ----------- ---------------------------- 2/7 [langchain-core]
#       Successfully uninstalled langchain-openai-1.1.12
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-openai]
#    ----------------- ---------------------- 3/7 [langchain-openai]
#    ----------------- ---------------------- 3/7 [langchain-openai]
#   Attempting uninstall: langgraph-prebuilt
#    ----------------- ---------------------- 3/7 [langchain-openai]
#     Found existing installation: langgraph-prebuilt 1.0.9
#    ----------------- ---------------------- 3/7 [langchain-openai]
#     Uninstalling langgraph-prebuilt-1.0.9:
#    ----------------- ---------------------- 3/7 [langchain-openai]
#       Successfully uninstalled langgraph-prebuilt-1.0.9
#    ----------------- ---------------------- 3/7 [langchain-openai]
#   Attempting uninstall: langgraph
#    ----------------- ---------------------- 3/7 [langchain-openai]
#    ---------------------------- ----------- 5/7 [langgraph]
#     Found existing installation: langgraph 1.1.6
#    ---------------------------- ----------- 5/7 [langgraph]
#     Uninstalling langgraph-1.1.6:
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#       Successfully uninstalled langgraph-1.1.6
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#   Attempting uninstall: langchain
#    ---------------------------- ----------- 5/7 [langgraph]
#     Found existing installation: langchain 1.2.15
#    ---------------------------- ----------- 5/7 [langgraph]
#     Uninstalling langchain-1.2.15:
#    ---------------------------- ----------- 5/7 [langgraph]
#       Successfully uninstalled langchain-1.2.15
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed langchain-1.2.18 langchain-core-1.3.3 langchain-openai-1.2.1 langchain-protocol-0.0.15 langgraph-1.1.10 langgraph-prebuilt-1.0.13 openai-2.36.0
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
retriver = WikipediaRetriever(top_k_results=2, lang='en')

# %%
query = 'Write about the culture of USA'
docs = retriever.invoke(query)

# %%
print(docs)
# Out:
# [Document(metadata={'title': 'Hillbilly Elegy', 'summary': "Hillbilly Elegy: A Memoir of a Family and Culture in Crisis is a 2016 memoir by JD Vance about the Appalachian values of his family from Kentucky and the socioeconomic problems of his hometown of Middletown, Ohio, where his mother's parents moved when they were young. It was adapted into the 2020 film Hillbilly Elegy, directed by Ron Howard and starring Glenn Close and Amy Adams.\nLater, Vance progressed in public service, becoming a senator from Ohio in 2023 and the vice president of the United States in 2025.", 'source': 'https://en.wikipedia.org/wiki/Hillbilly_Elegy'}, page_content='Hillbilly Elegy: A Memoir of a Family and Culture in Crisis is a 2016 memoir by JD Vance about the Appalachian values of his family from Kentucky and the socioeconomic problems of his hometown of Middletown, Ohio, where his mother\'s parents moved when they were young. It was adapted into the 2020 film Hillbilly Elegy, directed by Ron Howard and starring Glenn Close and Amy Adams.\nLater, Vance progressed in public service, becoming a senator from Ohio in 2023 and the vice president of the United States in 2025.\n\n\n== Summary ==\n\nVance describes his upbringing and family background while growing up in Middletown, Ohio, where his mother and her family had moved after World War II from Breathitt County, Kentucky.\nVance states that their Appalachian culture valued traits such as loyalty and love of country despite family violence and verbal abuse. Vance recounts his grandparents\' alcoholism as well as his mother\'s history of drug addictions and failed relationships. Vance\'s grandparents reconciled and became his guardians. His strict but loving grandmother pushed Vance, who went on to complete undergraduate studies at Ohio State University and earned a Juris Doctor degree from Yale Law School.\nVance raises questions about the responsibility of his family and local people for their misfortunes. Vance suggests that hillbilly culture fosters social disintegration and economic insecurity in Appalachia. He cites a personal experience where, while working as a grocery store cashier, he saw welfare recipients with cell phones when he could not afford one.\nVance\'s antipathy toward those who seemed to profit from poor behavior while he struggled is presented as a rationale for Appalachia\'s political swing from voting Democratic to a strong Republican affiliation. Vance tells stories highlighting the lack of work ethic of the local people, including the story of a man who quit his job after expressing dislike over his work hours, and a co-worker with a pregnant girlfriend who skipped work unexcused.\n\n\n== Publication ==\nIn July 2016, Hillbilly Elegy was popularized by an interview with Vance in The American Conservative. The volume of requests briefly disabled the website. Halfway through August, The New York Times wrote that the title had remained in the top ten Amazon bestsellers since the interview\'s publication.\nVance has credited his Yale contract law professor Amy Chua as the "authorial godmother" of the book, as she persuaded him to write the memoir.\n\n\n== Reception and legacy ==\n\n\n=== Critical reception ===\nThe book reached the top of The New York Times best seller list in August 2016 and January 2017.\n\nIn a positive review in The New York Times, Jennifer Senior wrote that Vance\'s confrontation of a social taboo was admirable, regardless of whether the reader agreed with his conclusions. She described the book as "a compassionate, discerning sociological analysis of the white underclass that has helped drive the politics of rebellion, particularly the ascent of Donald J. Trump." Senior wrote that Vance\'s subject is despair, and his argument was more generous in that it blames fatalism and learned helplessness rather than indolence.\nA 2017 Brookings Institution report noted that "J. D. Vance\'s Hillbilly Elegy became a national bestseller for its raw, emotional por ...

# %%
for i, doc in enumerate(docs, 1):
    print(f"\n===== Result {i} =====")
    print(doc.page_content)
    print("\nMetadata:", doc.metadata)
    print("=" * 80)
# Out:
# ===== Result 1 =====
# Hillbilly Elegy: A Memoir of a Family and Culture in Crisis is a 2016 memoir by JD Vance about the Appalachian values of his family from Kentucky and the socioeconomic problems of his hometown of Middletown, Ohio, where his mother's parents moved when they were young. It was adapted into the 2020 film Hillbilly Elegy, directed by Ron Howard and starring Glenn Close and Amy Adams.
# Later, Vance progressed in public service, becoming a senator from Ohio in 2023 and the vice president of the United States in 2025.
#
#
# == Summary ==
#
# Vance describes his upbringing and family background while growing up in Middletown, Ohio, where his mother and her family had moved after World War II from Breathitt County, Kentucky.
# Vance states that their Appalachian culture valued traits such as loyalty and love of country despite family violence and verbal abuse. Vance recounts his grandparents' alcoholism as well as his mother's history of drug addictions and failed relationships. Vance's grandparents reconciled and became his guardians. His strict but loving grandmother pushed Vance, who went on to complete undergraduate studies at Ohio State University and earned a Juris Doctor degree from Yale Law School.
# Vance raises questions about the responsibility of his family and local people for their misfortunes. Vance suggests that hillbilly culture fosters social disintegration and economic insecurity in Appalachia. He cites a personal experience where, while working as a grocery store cashier, he saw welfare recipients with cell phones when he could not afford one.
# Vance's antipathy toward those who seemed to profit from poor behavior while he struggled is presented as a rationale for Appalachia's political swing from voting Democratic to a strong Republican affiliation. Vance tells stories highlighting the lack of work ethic of the local people, including the story of a man who quit his job after expressing dislike over his work hours, and a co-worker with a pregnant girlfriend who skipped work unexcused.
#
#
# == Publication ==
# In July 2016, Hillbilly Elegy was popularized by an interview with Vance in The American Conservative. The volume of requests briefly disabled the website. Halfway through August, The New York Times wrote that the title had remained in the top ten Amazon bestsellers since the interview's publication.
# Vance has credited his Yale contract law professor Amy Chua as the "authorial godmother" of the book, as she persuaded him to write the memoir.
#
#
# == Reception and legacy ==
#
#
# === Critical reception ===
# The book reached the top of The New York Times best seller list in August 2016 and January 2017.
#
# In a positive review in The New York Times, Jennifer Senior wrote that Vance's confrontation of a social taboo was admirable, regardless of whether the reader agreed with his conclusions. She described the book as "a compassionate, discerning sociological analysis of the white underclass that has helped drive the politics of rebellion, particularly the ascent of Donald J. Trump." Senior wrote that Vance's subject is despair, and his argument was more generous in that it blames fatalism and learned helplessness rather than indolence.
# A 2017 Brookings Institution report noted that "J. D. Vance's Hillbilly Elegy became a national bestseller for its raw, emotional portrait of growing up in and eventually out of a poor rural community riddled by drug addiction and instability." Vance's account anecdotally confirmed the report's conclusion that family stability is essential to upward mobility.
# In an interview with Süddeutsche Zeitung in July 2023, German chancellor Olaf Scholz called the book "a very touching personal story of how a young man with poor starting conditions makes his way." Scholz said the book had moved him to tears, but that he found the positions Vance later took to be "tragic."
# The book was positively received by conservatives such as National Review columnist Mona Charen and National Review editor and Slate columnist Reihan
#
# Metadata: {'title': 'Hillbilly Elegy', 'summary': "Hillbilly Elegy: A Memoir of a Family and Culture in Crisis is a 2016 memoir by JD Vance about the Appalachian values of his family from Kentucky and the socioeconomic problems of his hometown of Middletown, Ohio, where his mother's parents moved when they were young. It was adapted into the 2020 film Hillbilly Elegy, directed by Ron Howard and starring Glenn Close and Amy Adams.\nLater, Vance progressed in public service, becoming a senator from Ohio in 2023 and the vice president of the United States in 2025.", 'source': 'https://en.wikipedia.org/wiki/Hillbilly_Elegy'}
# ================================================================================
#
# ===== Result 2 =====
# Each entry on this list of common misconceptions is worded as a correction; the misconceptions themselves are implied rather than stated. These entries are concise summaries; the main subject articles can be consulted for more detail.
#
#
# == Business ==
# Federal legal tender laws in the United States do not require that private businesses, persons, or organizations accept cash for payment, though it must be treated as valid payment for debts when tendered to a creditor.
# Adidas is not an acronym for "All day I dream about sports", "All day I dream about soccer", or "All day I dream about sex". The company was named after its founder Adolf "Adi" Dassler in 1949. The earliest publication found of the latter backronym was in 1978, as a joke.
# The letters "AR" in AR-15 stand for "ArmaLite Rifle", reflecting the company ArmaLite that originally manufactured the weapon. They do not stand for "assault rifle".
#
# The Coca-Cola bottle's contour bottle was not designed by the industrial designer Raymond Loewy.
# The common image of Santa Claus (Father Christmas) as a large jolly man in red garments was not created by the Coca-Cola Company as an advertising tool. Santa Claus had already taken this form in American popular culture by the late 19th century, long before Coca-Cola used his image in the 1930s.
# The Chevrolet Nova sold well in Latin American markets; General Motors did not rename the car. While no va does mean "doesn't go" in Spanish, nova was easily understood to mean "new".
# Netflix was not founded after its co-founder Reed Hastings was charged a $40 late fee by Blockbuster. Hastings made the story up to summarize Netflix's value proposition; Netflix's founders were actually inspired by Amazon.
# PepsiCo in no real sense ever owned the "6th most powerful navy" in the world after a deal with the Soviet Union. In 1989, Pepsi acquired several decommissioned warships as part of a barter deal. The oil tankers were leased out or sold and the other ships sold for scrap. A follow-on deal involved another 10 ships.
#
#
# == Fine arts ==
#
# Ancient Greek and Roman sculptures were originally painted in colors; they appear white today only because the original pigments have deteriorated. Some well-preserved statues still bear traces of their original coloration.
# Michelangelo was standing, not lying down, while painting the ceiling of the Sistine Chapel.
#
#
# == Food and cooking ==
#
# Searing does not seal in moisture in meat; it causes it to lose some moisture. Meat is seared to brown it and to affect its color, flavor, and texture.
# Braising meat does not add moisture; it causes it to lose some moisture. Moisture appears to be added when the gentle cooking breaks down connective tissue and collagen, which lubricates and tenderizes fibers.
# Mussels and clams that do not open when cooked can still be fully cooked and safe to eat.
# Twinkies, an American snack cake generally considered to be "junk food", have a shelf life of around 25 days, despite the (usually facetious) common claim that they remain edible for decades. The official shelf life is 45 days. Twinkies normally remain on a store shelf for 7 to 10 days.
# Packaged foods, when properly stored, can safely be eaten past their "expiration" dates in the US. While some US states regulate expiration dates for some products, and they're required federally for infant formula, generally "use-by" and "best-by" dates are manufacturer suggestions for best quality.
# Storing bread in the refrigerator makes it go stale faster than leaving it at room temperature. It does, however, slow mold growth.
#
# Crystallized honey is not spoiled. The crystals are formed by low temperature crystallization, a high glucose level, and the presence of pollen. The crystallization can be reversed by gentle heating.
# Seeds are not the spiciest part of chili peppers. In fact, seeds contain a low amount of capsaicin, one of several compounds which induce the hot sensation (pungency) in mammals. The highest concentration of capsaicin is located in
#
# Metadata: {'title': 'List of common misconceptions about arts and culture', 'summary': 'Each entry on this list of common misconceptions is worded as a correction; the misconceptions themselves are implied rather than stated. These entries are concise summaries; the main subject articles can be consulted for more detail.\n\n', 'source': 'https://en.wikipedia.org/wiki/List_of_common_misconceptions_about_arts_and_culture'}
# ================================================================================
